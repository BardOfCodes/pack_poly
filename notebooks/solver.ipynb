# %%
import cairosvg
from geopatterns import GeoPattern
import random
import uuid

random.seed(10)
uuid.UUID(int=random.getrandbits(10))
pattern_types = ["bricks", "hexagons", "overlapping_circles", "overlapping_rings", "plaid", "plus_signs", "rings", "sinewaves", "squares", "triangles", "xes"]
pattern_types = ["bricks", "hexagons", "overlapping_circles", "overlapping_rings", "plaid", "plus_signs", "rings", "squares", "triangles", "xes"]
for i in range(20):
    pattern = GeoPattern(str(uuid.uuid4()) ,random.choice(pattern_types))
    cairosvg.svg2png(bytestring=pattern.svg_string, write_to=f"tmp_{i}.png", dpi=300, scale=5.0)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 __dir__(GeoPattern)
#
# NameError: name '__dir__' is not defined

# %%
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline
import torch as th
import numpy as np
import sys
sys.path.insert(0, '../')
from csg_lib import CSG2DExecutor
from generator.map_solve import generate_puzzle
import viz.visualize as viz
# %autoreload 2
# Out:
# UsageError: Line magic function `%autoreload` not found.

# %%
res = 64
old_map, new_map, polys, positions = generate_puzzle(res, 32)

# %%
plt.figure(figsize=(20, 10))
plt.subplot(1, 2, 1)
plt.imshow(old_map, cmap='gray')
plt.subplot(1, 2, 2)
plt.imshow(new_map, cmap='gray')

# %%
new_map[2]
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True, False, False, False,  True,
#         True, False, False, False, False,  True, False, False,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True])

# %%
viz.draw_packing(polys, positions, res, res)

# %%
polys, positions
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 polys, positions
#
# NameError: name 'polys' is not defined
